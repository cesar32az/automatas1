# %%
from mini_afd import *

# %%
afd = FSM.fromFile("AFD.txt")

# %%
# %matplotlib notebook
afd.display()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
minafd = afd.minimize()

# %%
# %matplotlib notebook
minafd.display()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
minafd.toFile("min_afd.txt")
