# %%
from mini_afd import *

# %%
afd = AFD.fromFile("AFD.txt")

# %%
# %matplotlib notebook
afd.display()
# Out:
# <img src="data:image/png;base64,..." width="735">

# %%
minafd = afd.minimize()

# %%
# %matplotlib notebook
minafd.display()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
minafd.toFile("min_afd.txt")
